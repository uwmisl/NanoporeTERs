# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from sklearn.model_selection import train_test_split
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import math as m
import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = "/disk1/pore_data/NanoporeTERs/"

# %%
'''
Loading Data
'''
Y_file = np.load(os.path.join(data_dir, 'Y00_Y08_LBset&set1set2set3_MinIONNoise_LBNoise_EcoliNoise_classes_05142019.npy'))
X_file = np.load(os.path.join(data_dir, 'Y00_Y08_LBset&set1set2set3_MinIONNoise_LBNoise_EcoliNoise_raw20000_05142019.npy'))
print('Data loaded successfully')

Y_file = Y_file.flatten()

window_length = 19881
X_file = X_file[:, :window_length]
# Out:
# Data loaded successfully

# %%
'''
Train, test split
'''
X_train = X_file.reshape(
    len(X_file), X_file.shape[1], 1)
labels_train = Y_file

X_tr, X_vld, lab_tr, lab_vld = train_test_split(
    X_train, labels_train, stratify=labels_train, train_size=0.8)

X_vld, X_test, lab_vld, lab_test = train_test_split(
    X_vld, lab_vld, stratify=lab_vld)

y_tr = lab_tr.astype(int)
y_vld = lab_vld.astype(int)
y_test = lab_test.astype(int)

print('Data split done')
# Out:
# Data split done

# %%
'''
If gpu is available we will use it
'''
use_cuda = True

# %%
'''
Reshaping data
'''
reshape = 141

X_tr = X_tr.reshape(len(X_tr), 1, reshape, reshape)
X_vld = X_vld.reshape(len(X_vld), 1, reshape, reshape)
X_test = X_test.reshape(len(X_test), 1, reshape, reshape)
print('Data reshaping done')
# Out:
# Data reshaping done

# %%
'''
Zipping data together and storing in trainloader objects
'''
train_set = list(zip(X_tr, y_tr))
val_set = list(zip(X_vld, y_vld))
test_set = list(zip(X_test, y_test))
print('Done zipping and converting')
# Out:
# Done zipping and converting

# %%
'''
Creating the neural net
'''


class CNN(nn.Module):

    def __init__(self):
        self.O_1 = 17
        self.O_2 = 18
        self.O_3 = 32
        self.O_4 = 37

        self.K_1 = 3
        self.K_2 = 1
        self.K_3 = 4
        self.K_4 = 2

        self.KP_1 = 4
        self.KP_2 = 4
        self.KP_3 = 1
        self.KP_4 = 1

        self.conv_linear_out = int(m.floor((m.floor((m.floor((m.floor((m.floor((reshape - self.K_1 + 1)/self.KP_1) -
                                                                       self.K_2 + 1)/self.KP_2) - self.K_3 + 1)/self.KP_3) - self.K_4 + 1)/self.KP_4)**2)*self.O_4))

        self.FN_1 = 148

        super(CNN, self).__init__()

        self.conv1 = nn.Sequential(nn.Conv2d(1, self.O_1, self.K_1), nn.ReLU(),
                                   nn.MaxPool2d(self.KP_1))
        self.conv2 = nn.Sequential(nn.Conv2d(self.O_1, self.O_2, self.K_2), nn.ReLU(),
                                   nn.MaxPool2d(self.KP_2))
        self.conv3 = nn.Sequential(nn.Conv2d(self.O_2, self.O_3, self.K_3), nn.ReLU(),
                                   nn.MaxPool2d(self.KP_3))
        self.conv4 = nn.Sequential(nn.Conv2d(self.O_3, self.O_4, self.K_4), nn.ReLU(),
                                   nn.MaxPool2d(self.KP_4))
        self.fc1 = nn.Linear(self.conv_linear_out, self.FN_1, nn.Dropout(0.2))
        self.fc2 = nn.Linear(self.FN_1, 10)

    def forward(self, x):
        x = x.float()
        x = F.leaky_relu(self.conv1(x))
        x = F.leaky_relu(self.conv2(x))
        x = F.leaky_relu(self.conv3(x))
        x = F.leaky_relu(self.conv4(x))
        x = x.view(len(x), -1)
        x = F.logsigmoid(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
'''
Train
'''

best_accuracy = -float('Inf')
best_params = []

batch_size = 30

trainloader = torch.utils.data.DataLoader(
    train_set, batch_size=batch_size, shuffle=True, num_workers=2)
vldloader = torch.utils.data.DataLoader(
    val_set, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(
    test_set, batch_size=batch_size, shuffle=True, num_workers=2)

lr = 0.001
epochs = 250
momentum = 0.7557312793639288

net = CNN()

if use_cuda and torch.cuda.is_available():
    net.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)

for epoch in range(250):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        if use_cuda and torch.cuda.is_available():
            inputs = inputs.cuda()
            labels = labels.cuda()

        optimizer.zero_grad()
        outputs = net(inputs)
        outputs = outputs.to(dtype=torch.float64)
        labels = labels.to(dtype=torch.long)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    print('Finished epoch number ' + str(epoch))

    correct = 0
    total = 0
    with torch.no_grad():
        for data in vldloader:
            inputs, labels = data
            inputs = inputs.cuda()
            labels = labels.cuda()
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += len(labels)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the validation set: %d %%'
          % (100 * correct / total))
# Out:
# Finished epoch number 0
# Accuracy of the network on the validation set: 10 %
# Finished epoch number 1
# Accuracy of the network on the validation set: 10 %
# Finished epoch number 2
# Accuracy of the network on the validation set: 10 %
# Finished epoch number 3
# Accuracy of the network on the validation set: 10 %
# Finished epoch number 4
# Accuracy of the network on the validation set: 28 %
# Finished epoch number 5
# Accuracy of the network on the validation set: 41 %
# Finished epoch number 6
# Accuracy of the network on the validation set: 53 %
# Finished epoch number 7
# Accuracy of the network on the validation set: 60 %
# Finished epoch number 8
# Accuracy of the network on the validation set: 63 %
# Finished epoch number 9
# Accuracy of the network on the validation set: 65 %
# Finished epoch number 10
# Accuracy of the network on the validation set: 66 %
# Finished epoch number 11
# Accuracy of the network on the validation set: 67 %
# Finished epoch number 12
# Accuracy of the network on the validation set: 68 %
# Finished epoch number 13
# Accuracy of the network on the validation set: 69 %
# Finished epoch number 14
# Accuracy of the network on the validation set: 68 %
# Finished epoch number 15
# Accuracy of the network on the validation set: 69 %
# Finished epoch number 16
# Accuracy of the network on the validation set: 65 %
# Finished epoch number 17
# Accuracy of the network on the validation set: 70 %
# Finished epoch number 18
# Accuracy of the network on the validation set: 72 %
# Finished epoch number 19
# Accuracy of the network on the validation set: 73 %
# Finished epoch number 20
# Accuracy of the network on the validation set: 71 %
# Finished epoch number 21
# Accuracy of the network on the validation set: 74 %
# Finished epoch number 22
# Accuracy of the network on the validation set: 74 %
# Finished epoch number 23
# Accuracy of the network on the validation set: 73 %
# Finished epoch number 24
# Accuracy of the network on the validation set: 75 %
# Finished epoch number 25
# Accuracy of the network on the validation set: 75 %
# Finished epoch number 26
# Accuracy of the network on the validation set: 75 %
# Finished epoch number 27
# Accuracy of the network on the validation set: 75 %
# Finished epoch number 28
# Accuracy of the network on the validation set: 75 %
# Finished epoch number 29
# Accuracy of the network on the validation set: 73 %
# Finished epoch number 30
# Accuracy of the network on the validation set: 76 %
# Finished epoch number 31
# Accuracy of the network on the validation set: 76 %
# Finished epoch number 32
# Accuracy of the network on the validation set: 76 %
# Finished epoch number 33
# Accuracy of the network on the validation set: 76 %
# Finished epoch number 34
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 35
# Accuracy of the network on the validation set: 75 %
# Finished epoch number 36
# Accuracy of the network on the validation set: 74 %
# Finished epoch number 37
# Accuracy of the network on the validation set: 76 %
# Finished epoch number 38
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 39
# Accuracy of the network on the validation set: 73 %
# Finished epoch number 40
# Accuracy of the network on the validation set: 75 %
# Finished epoch number 41
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 42
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 43
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 44
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 45
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 46
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 47
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 48
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 49
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 50
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 51
# Accuracy of the network on the validation set: 76 %
# Finished epoch number 52
# Accuracy of the network on the validation set: 75 %
# Finished epoch number 53
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 54
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 55
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 56
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 57
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 58
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 59
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 60
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 61
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 62
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 63
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 64
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 65
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 66
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 67
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 68
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 69
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 70
# Accuracy of the network on the validation set: 77 %
# Finished epoch number 71
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 72
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 73
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 74
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 75
# Accuracy of the network on the validation set: 76 %
# Finished epoch number 76
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 77
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 78
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 79
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 80
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 81
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 82
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 83
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 84
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 85
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 86
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 87
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 88
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 89
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 90
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 91
# Accuracy of the network on the validation set: 78 %
# Finished epoch number 92
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 93
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 94
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 95
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 96
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 97
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 98
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 99
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 100
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 101
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 102
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 103
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 104
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 105
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 106
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 107
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 108
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 109
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 110
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 111
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 112
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 113
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 114
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 115
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 116
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 117
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 118
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 119
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 120
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 121
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 122
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 123
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 124
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 125
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 126
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 127
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 131
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 132
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 133
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 134
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 135
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 136
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 137
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 138
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 139
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 140
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 141
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 142
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 143
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 144
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 145
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 146
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 147
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 148
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 149
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 150
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 151
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 152
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 153
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 154
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 155
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 156
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 157
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 158
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 159
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 160
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 161
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 162
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 163
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 164
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 165
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 166
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 167
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 168
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 169
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 170
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 171
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 172
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 173
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 174
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 175
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 176
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 177
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 178
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 179
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 180
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 181
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 182
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 183
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 184
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 185
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 186
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 187
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 188
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 189
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 190
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 191
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 192
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 193
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 194
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 195
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 196
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 197
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 198
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 199
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 200
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 201
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 202
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 203
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 204
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 205
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 206
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 207
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 208
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 209
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 210
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 211
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 212
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 213
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 214
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 215
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 216
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 217
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 218
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 219
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 220
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 221
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 222
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 223
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 224
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 225
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 226
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 227
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 228
# Accuracy of the network on the validation set: 79 %
# Finished epoch number 229
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 230
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 231
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 232
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 233
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 234
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 235
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 236
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 237
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 238
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 239
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 240
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 241
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 242
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 243
# Accuracy of the network on the validation set: 81 %
# Finished epoch number 244
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 245
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 246
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 247
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 248
# Accuracy of the network on the validation set: 80 %
# Finished epoch number 249
# Accuracy of the network on the validation set: 80 %

# %%
'''
Test
'''
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        inputs, labels = data
        inputs = inputs.cuda()
        labels = labels.cuda()
        outputs = net(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += len(labels)
        correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the test set: %d %%'
          % (100 * correct / total))

text_file = open(os.path.join(data_dir, "NTERs_trained_cnn_results_05152019.txt"), "w")
text_file.write("Accuracy of the network on the test set: %d %%" %
                (100 * correct / total))
text_file.close()
# Out:
# Accuracy of the network on the test set: 80 %

# %%
	
'''
Saving the trained net
'''
	
#torch.save(net, '/disk1/pore_data/jeff_saved/NTERs_trained_cnn_05152019.pt')
# Out:
# '\nSaving the trained net\n'
